# %%
import pandas as pd

# %%
players = ["hwoarang", "miguel","kazuya","bryan"]
pd.Series(players)
# Out:
# 0    hwoarang
# 1      miguel
# 2      kazuya
# 3       bryan
# dtype: object

# %%
profile = {"name":"raj kumar","age":"23", "location":"delhi"}
ds = pd.Series(profile)
ds.sum()
# Out:
# '23delhiraj kumar'

# %%
nums = [2.3,23.2,42.2,4]
ns = pd.Series(nums)
ns.product()
# Out:
# 9007.1679999999997

# %%
ns.mean()
# Out:
# 17.925

# %% [markdown]
# # reading csv files, use squeeze so that pandas take it as a series and not as data frame

# %%
pokemons = pd.read_csv("pokemon.csv", usecols=["Pokemon"], squeeze=True)
pokemons.head()
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# Name: Pokemon, dtype: object

# %%
google = pd.read_csv("google_stock_price.csv", squeeze=True)
google.head()
# Out:
# 0    50.12
# 1    54.10
# 2    54.65
# 3    52.38
# 4    52.95
# Name: Stock Price, dtype: float64

# %%
#head() and tail() methods

# %%
pokemons.head(n=10)
# Out:
# 0     Bulbasaur
# 1       Ivysaur
# 2      Venusaur
# 3    Charmander
# 4    Charmeleon
# 5     Charizard
# 6      Squirtle
# 7     Wartortle
# 8     Blastoise
# 9      Caterpie
# Name: Pokemon, dtype: object

# %%
pokemons.tail()
# Out:
# 716      Yveltal
# 717      Zygarde
# 718      Diancie
# 719        Hoopa
# 720    Volcanion
# Name: Pokemon, dtype: object

# %% [markdown]
# # dir() --> returns all methods and attributes applicable on the object

# %%
dir(pokemons)
# Out:
# ['T',
#  '_AXIS_ALIASES',
#  '_AXIS_IALIASES',
#  '_AXIS_LEN',
#  '_AXIS_NAMES',
#  '_AXIS_NUMBERS',
#  '_AXIS_ORDERS',
#  '_AXIS_REVERSED',
#  '_AXIS_SLICEMAP',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__array__',
#  '__array_prepare__',
#  '__array_priority__',
#  '__array_wrap__',
#  '__bool__',
#  '__bytes__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__div__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__float__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__int__',
#  '__invert__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__le__',
#  '__len__',
#  '__long__',
#  '__lt__',
#  '__mod__',
#  '__module__',
#  '__mul__',
#  '__ne__',
#  '__neg__',
# ...

# %% [markdown]
# # sorting values

# %%
sorted(pokemons)
# Out:
# ['Abomasnow',
#  'Abra',
#  'Absol',
#  'Accelgor',
#  'Aegislash',
#  'Aerodactyl',
#  'Aggron',
#  'Aipom',
#  'Alakazam',
#  'Alomomola',
#  'Altaria',
#  'Amaura',
#  'Ambipom',
#  'Amoonguss',
#  'Ampharos',
#  'Anorith',
#  'Arbok',
#  'Arcanine',
#  'Arceus',
#  'Archen',
#  'Archeops',
#  'Ariados',
#  'Armaldo',
#  'Aromatisse',
#  'Aron',
#  'Articuno',
#  'Audino',
#  'Aurorus',
#  'Avalugg',
#  'Axew',
#  'Azelf',
#  'Azumarill',
#  'Azurill',
#  'Bagon',
#  'Baltoy',
#  'Banette',
#  'Barbaracle',
#  'Barboach',
#  'Basculin',
#  'Bastiodon',
#  'Bayleef',
#  'Beartic',
#  'Beautifly',
#  'Beedrill',
#  'Beheeyem',
#  'Beldum',
#  'Bellossom',
#  'Bellsprout',
#  'Bergmite',
#  'Bibarel',
#  'Bidoof',
#  'Binacle',
#  'Bisharp',
#  'Blastoise',
#  'Blaziken',
#  'Blissey',
#  'Blitzle',
#  'Boldore',
#  'Bonsly',
#  'Bouffalant',
#  'Braixen',
#  'Braviary',
#  'Breloom',
#  'Bronzong',
#  'Bronzor',
#  'Budew',
#  'Buizel',
#  'Bulbasaur',
#  'Buneary',
#  'Bunnelby',
# ...

# %%
pokemons.sort_values(ascending=False).head()
# Out:
# 717     Zygarde
# 633    Zweilous
# 40        Zubat
# 569       Zorua
# 570     Zoroark
# Name: Pokemon, dtype: object

# %%
pokemons.sort_values(inplace=True)

# %%
100 in pokemons.values
# Out:
# False

# %%
100 in pokemons.index
# Out:
# True

# %%
pokemons.head(2)
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# Name: Pokemon, dtype: object

# %%
"Bulbasaur" in pokemons
# Out:
# False

# %%
"Bulbasaur" in pokemons.values
# Out:
# True

# %%
pokemons.get_value(0)
# Out:
# 'Bulbasaur'

# %% [markdown]
# # can treat the series like list ########

# %%
pokemons[100]
# Out:
# 'Electrode'

# %%
pokemons[[100,101,102]]
# Out:
# 100    Electrode
# 101    Exeggcute
# 102    Exeggutor
# Name: Pokemon, dtype: object

# %%
pokemons[0:3]
# Out:
# 0    Bulbasaur
# 1      Ivysaur
# 2     Venusaur
# Name: Pokemon, dtype: object
